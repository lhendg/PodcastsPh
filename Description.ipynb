# %%
import requests
import pattern3.web as web
import pandas as pd 
import numpy as np 
from bs4 import BeautifulSoup
import re
import pickle

# %%
data = pd.read_excel('data/Spotify_Top Charts.xlsx')

# %%
data = data.dropna()
data.shape
# Out:
# (95, 3)

# %%
ID = data['ID'].astype(int, errors='ignore')
url = 'https://podcasts.apple.com/us/podcast/id'

# %%
links = []
for i in ID: links.append(url+str(i))

# %%
columns = ['ID', 'Link', 'Description']
df = pd.DataFrame(columns=columns)

# %%
df['ID'] = data['ID'].map(int)
df['Link'] = links
df = df.reset_index(drop=True)
df
# Out:
#             ID                                               Link Description
# 0   1459227062  https://podcasts.apple.com/us/podcast/id145922...         NaN
# 1   1387922676  https://podcasts.apple.com/us/podcast/id138792...         NaN
# 2   1439313975  https://podcasts.apple.com/us/podcast/id143931...         NaN
# 3   1455713016  https://podcasts.apple.com/us/podcast/id145571...         NaN
# 4    160904630  https://podcasts.apple.com/us/podcast/id160904630         NaN
# ..         ...                                                ...         ...
# 90  1477350613  https://podcasts.apple.com/us/podcast/id147735...         NaN
# 91  1393035987  https://podcasts.apple.com/us/podcast/id139303...         NaN
# 92   151230264  https://podcasts.apple.com/us/podcast/id151230264         NaN
# 93  1195370480  https://podcasts.apple.com/us/podcast/id119537...         NaN
# 94   394775318  https://podcasts.apple.com/us/podcast/id394775318         NaN
#
# [95 rows x 3 columns]

# %%
describe = []

# %%
for link in df['Link']: 
    response = requests.get(link) 
    content =  BeautifulSoup(response.text, 'html.parser')
    
    description = content.find('section', 'product-hero-desc__section')
    if description is not None:
        descr_parag = description.find('p')
        podcast = descr_parag.getText()
    else: 
        podcast = 0
    describe.append(podcast)
    
    dur = []
    duration = content.findAll('li', 'inline-list__item inline-list__item--margin-inline-start-small')
    for time in duration:
        a = time.getText()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ec74a3eb6690> in <module>
#      15
#      16     track_list = content.find('div', 'track-list', 'podcast')
# ---> 17     episodes = track_list.findAll('tr', 'podcast-episode')
#      18     episode_count = len(episodes)
#      19     durations = []
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
df['Description'] = describe

# %%
df.to_excel('trying.xlsx')

# %%
content
# Out:
# <!DOCTYPE html>
#
# <html lang="en-us" prefix="og: http://ogp.me/ns#" xml:lang="en-us">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
# ...

# %%
hehe = content.findAll('li', 'inline-list__item inline-list__item--margin-inline-start-small')
hones = []

# %%
for i in hehe:
    a = i.getText()
    hones.append(a)

# %%
x = [item for subitem in hones for item in subitem.split() if item.isdigit()]

# %%
x.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-182-8fa448f74293> in <module>
# ----> 1 x.type
#
# AttributeError: 'list' object has no attribute 'type'

# %%
for i in x: 
    y = int(i)
    print(y)
# Out:
# []
# []
# []
# []
# []
# []

# %%
(x[0])
# Out:
# '24'
