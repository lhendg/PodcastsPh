# %% [markdown]
# # Importing Packages

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp

from sklearn import preprocessing

# %%
dataframe = pd.read_excel('Podcast_data.xlsx')

# %%
data = dataframe

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'wrapperType', 'kind', 'collectionId', 'trackId',
#        'artistName', 'collectionName', 'trackName', 'collectionCensoredName',
#        'trackCensoredName', 'collectionViewUrl', 'feedUrl', 'trackViewUrl',
#        'artworkUrl30', 'artworkUrl60', 'artworkUrl100', 'collectionPrice',
#        'trackPrice', 'trackRentalPrice', 'collectionHdPrice', 'trackHdPrice',
#        'trackHdRentalPrice', 'releaseDate', 'collectionExplicitness',
#        'trackExplicitness', 'trackCount', 'country', 'currency',
#        'primaryGenreName', 'contentAdvisoryRating', 'artworkUrl600',
#        'genreIds', 'genres', 'artistId', 'artistViewUrl'],
#       dtype='object')

# %%
data = data.drop(['Unnamed: 0', 'wrapperType', 'trackName', 'kind', 'collectionId', 'collectionCensoredName',
       'trackCensoredName', 'collectionViewUrl', 'feedUrl', 'trackViewUrl',
       'artworkUrl30', 'artworkUrl60', 'artworkUrl100', 'trackPrice', 'trackRentalPrice', 'collectionHdPrice', 'trackHdPrice',
       'trackHdRentalPrice', 'currency', 'artworkUrl600', 'genreIds', 'artistViewUrl', 'country', 'trackExplicitness',  
        'collectionPrice', 'collectionExplicitness', 'artistId'], axis=1)

# %%
data
# Out:
#          trackId                            artistName  \
# 0     1101180313                    Barangay LS 97.1FM
# 1      160904630                                   TED
# 2      283605519           iHeartRadio & HowStuffWorks
# 3      256580326                       Immediate Media
# 4      542323934               info@rx931.com (RX93.1)
# ...          ...                                   ...
# 1180  1145721542                    Holistic Pet Radio
# 1181  1313060210                 NutriSource Pet Foods
# 1182  1400063694  Caitlin McColl and Kirstie McConnell
# 1183  1229498123                     Dr. Kathryn Primm
# 1184   371136011                  Page, Mike, and Luke
#
#                                          collectionName           releaseDate  \
# 0                                 Barangay Love Stories  2020-02-10T08:31:00Z
# 1                                       TED Talks Daily  2020-02-10T16:00:00Z
# ...
